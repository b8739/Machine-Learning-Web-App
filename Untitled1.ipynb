# %%
import pandas as pd

df = pd.read_csv('/Users/jeongjaeho/attic_project/testcode/data111.csv')

df
# Out:
#                     ts  700FIC028_Y  700II781C_Y  700II782C_Y  700II783C_Y  \
# 0      2016-07-12 0:00     32.17403    13.226080     13.53725     13.59742
# 1      2016-07-12 0:01     32.06405     9.414404     10.28217     10.32054
# 2      2016-07-12 0:02     32.20876     9.807193     11.52965     10.00512
# 3      2016-07-12 0:03     32.17450    15.399190     15.52878     15.61818
# 4      2016-07-12 0:04     32.15032    12.643540     12.54185     12.64877
# ...                ...          ...          ...          ...          ...
# 4994  2016-07-15 11:14     32.00462    15.770320     15.65841     15.71927
# 4995  2016-07-15 11:15     31.94653    11.744700     11.67167     11.71438
# 4996  2016-07-15 11:16     32.18319    10.562900     10.53658     10.70412
# 4997  2016-07-15 11:17     32.09569    16.052530     15.92344     16.98723
# 4998  2016-07-15 11:18     31.83692    14.769860     15.36486     15.67880
#
# ...

# %%
df2 = df['700FIC028_Y'].sample(n=500, random_state=1005)

# %%
df2.sort_index()
# Out:
# 13      32.14977
# 18      32.20551
# 23      32.20430
# 28      32.08506
# 35      32.06573
#           ...
# 4970    32.28155
# 4980    32.08950
# 4989    32.11723
# 4990    32.08456
# 4998    31.83692
# Name: 700FIC028_Y, Length: 500, dtype: float64

# %%
feature = 'CRIM'

# %%
featureName = []
featureName.append(feature)
print(featureName)
# Out:
# ['CRIM']
